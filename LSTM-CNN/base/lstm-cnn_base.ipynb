# %% [markdown]
# # Store Item Demand Forecasting with Baseline LSTM-CNN Regressor

# %% [markdown]
# ## Import required libraries

# %%
import pandas as pd
pd.options.display.max_columns = 12
pd.options.display.max_rows = 24

import warnings
warnings.simplefilter('ignore')

# %matplotlib inline
import matplotlib.pyplot as plt

import seaborn as sns
sns.set()

import numpy as np

# %config InlineBackend.figure_format = 'svg'

from pylab import rcParams
rcParams['figure.figsize'] = 5, 4

from itertools import product, starmap

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

from keras.models import Sequential, Model
from keras.layers import *

import time
from keras.callbacks import EarlyStopping,ModelCheckpoint
from keras.losses import MeanSquaredError

from keras import models 

from scipy.stats import describe
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ## Read datasets

# %%
# google colab
from google.colab import drive
drive.mount('/content/drive')

df_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ml project/train.csv', parse_dates = ['date'])
df_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ml project/test.csv', parse_dates = ['date'])
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# # jupyter
# df_train = pd.read_csv('train.csv', parse_dates = ['date'])
# df_test = pd.read_csv('test.csv', parse_dates = ['date'])

# %%
df_train.head()
# Out:
#         date  store  item  sales
# 0 2013-01-01      1     1     13
# 1 2013-01-02      1     1     11
# 2 2013-01-03      1     1     14
# 3 2013-01-04      1     1     13
# 4 2013-01-05      1     1     10

# %%
df_test.head()
# Out:
#    id       date  store  item
# 0   0 2018-01-01      1     1
# 1   1 2018-01-02      1     1
# 2   2 2018-01-03      1     1
# 3   3 2018-01-04      1     1
# 4   4 2018-01-05      1     1

# %% [markdown]
# ## Preprocess data

# %% [markdown]
# ### Convert strings to dates

# %%
df_train['date'] = pd.to_datetime(df_train['date'])
df_train.index = pd.DatetimeIndex(df_train['date'])
df_train.drop('date', axis=1, inplace=True)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 913000 entries, 2013-01-01 to 2017-12-31
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   store   913000 non-null  int64
#  1   item    913000 non-null  int64
#  2   sales   913000 non-null  int64
# dtypes: int64(3)
# memory usage: 27.9 MB

# %%
df_test['date'] = pd.to_datetime(df_test['date'])
df_test.index = pd.DatetimeIndex(df_test['date'])
df_test.drop('date', axis=1, inplace=True)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 45000 entries, 2018-01-01 to 2018-03-31
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      45000 non-null  int64
#  1   store   45000 non-null  int64
#  2   item    45000 non-null  int64
# dtypes: int64(3)
# memory usage: 1.4 MB

# %% [markdown]
# ### Sales for each storeitem

# %%
def storeitems():
    return product(range(1,51), range(1,11))


def storeitems_column_names():
    return list(starmap(lambda i,s: f'item_{i}_store_{s}_sales', storeitems()))


def sales_by_storeitem(df):
    ret = pd.DataFrame(index=df.index.unique())
    for i, s in storeitems():
        ret[f'item_{i}_store_{s}_sales'] = df[(df['item'] == i) & (df['store'] == s)]['sales'].values
    return ret

# %%
df_train = sales_by_storeitem(df_train)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1826 entries, 2013-01-01 to 2017-12-31
# Columns: 500 entries, item_1_store_1_sales to item_50_store_10_sales
# dtypes: int64(500)
# memory usage: 7.0 MB

# %% [markdown]
# ### Mock sales to use same transformations as train data

# %%
df_test['sales'] = np.zeros(df_test.shape[0])
df_test = sales_by_storeitem(df_test)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 90 entries, 2018-01-01 to 2018-03-31
# Columns: 500 entries, item_1_store_1_sales to item_50_store_10_sales
# dtypes: float64(500)
# memory usage: 352.3 KB

# %% [markdown]
# ### Combine train and test data

# %%
# ensure columns have same name and order
col_names = list(zip(df_test.columns, df_train.columns))
for cn in col_names:
    assert cn[0] == cn[1]

# %%
df_test['is_test'] = np.repeat(True, df_test.shape[0])
df_train['is_test'] = np.repeat(False, df_train.shape[0])
df_total = pd.concat([df_train, df_test])
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1916 entries, 2013-01-01 to 2018-03-31
# Columns: 501 entries, item_1_store_1_sales to is_test
# dtypes: bool(1), float64(500)
# memory usage: 7.3 MB

# %% [markdown]
# ### One-Hot encoding

# %%
weekday_df = pd.get_dummies(df_total.index.weekday, prefix='weekday')
weekday_df.index = df_total.index

weekday_df.head()
# Out:
#             weekday_0  weekday_1  weekday_2  weekday_3  weekday_4  weekday_5  \
# date
# 2013-01-01          0          1          0          0          0          0
# 2013-01-02          0          0          1          0          0          0
# 2013-01-03          0          0          0          1          0          0
# 2013-01-04          0          0          0          0          1          0
# 2013-01-05          0          0          0          0          0          1
#
#             weekday_6
# date
# 2013-01-01          0
# 2013-01-02          0
# 2013-01-03          0
# 2013-01-04          0
# 2013-01-05          0

# %%
month_df = pd.get_dummies(df_total.index.month, prefix='month')
month_df.index =  df_total.index

month_df.head()
# Out:
#             month_1  month_2  month_3  month_4  month_5  month_6  month_7  \
# date
# 2013-01-01        1        0        0        0        0        0        0
# 2013-01-02        1        0        0        0        0        0        0
# 2013-01-03        1        0        0        0        0        0        0
# 2013-01-04        1        0        0        0        0        0        0
# 2013-01-05        1        0        0        0        0        0        0
#
#             month_8  month_9  month_10  month_11  month_12
# date
# 2013-01-01        0        0         0         0         0
# 2013-01-02        0        0         0         0         0
# 2013-01-03        0        0         0         0         0
# 2013-01-04        0        0         0         0         0
# 2013-01-05        0        0         0         0         0

# %%
weekyear_df = pd.get_dummies(df_total.index.weekofyear, prefix='weekyear')
weekyear_df.index =  df_total.index

weekyear_df.head()
# Out:
#             weekyear_1  weekyear_2  weekyear_3  weekyear_4  weekyear_5  \
# date
# 2013-01-01           1           0           0           0           0
# 2013-01-02           1           0           0           0           0
# 2013-01-03           1           0           0           0           0
# 2013-01-04           1           0           0           0           0
# 2013-01-05           1           0           0           0           0
#
#             weekyear_6  ...  weekyear_48  weekyear_49  weekyear_50  \
# date                    ...
# 2013-01-01           0  ...            0            0            0
# 2013-01-02           0  ...            0            0            0
# 2013-01-03           0  ...            0            0            0
# 2013-01-04           0  ...            0            0            0
# 2013-01-05           0  ...            0            0            0
#
#             weekyear_51  weekyear_52  weekyear_53
# date
# 2013-01-01            0            0            0
# 2013-01-02            0            0            0
# 2013-01-03            0            0            0
# 2013-01-04            0            0            0
# 2013-01-05            0            0            0
#
# [5 rows x 53 columns]

# %%
quarter_df = pd.get_dummies(df_total.index.quarter, prefix='quarter')
quarter_df.index =  df_total.index

quarter_df.head()
# Out:
#             quarter_1  quarter_2  quarter_3  quarter_4
# date
# 2013-01-01          1          0          0          0
# 2013-01-02          1          0          0          0
# 2013-01-03          1          0          0          0
# 2013-01-04          1          0          0          0
# 2013-01-05          1          0          0          0

# %%
df_total = pd.concat([weekday_df, month_df, weekyear_df, quarter_df, df_total], axis=1)

df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1916 entries, 2013-01-01 to 2018-03-31
# Columns: 577 entries, weekday_0 to is_test
# dtypes: bool(1), float64(500), uint8(76)
# memory usage: 7.5 MB

# %%
assert df_total.isna().any().any() == False

# %% [markdown]
# ### Shift sales

# %%
def shift_series(series, days):
    return series.transform(lambda x: x.shift(days))


def shift_series_in_df(df, series_names=[], days_delta=90):
    """
    Shift columns in df with names in series_names by days_delta.
    
    Negative days_delta will prepend future values to current date,
    positive days_delta wil prepend past values to current date.
    """
    ret = pd.DataFrame(index=df.index.copy())
    str_sgn = 'future' if np.sign(days_delta) < 0 else 'past'
    for sn in series_names:
        ret[f'{sn}_{str_sgn}_{np.abs(days_delta)}'] = shift_series(df[sn], days_delta)
    return ret

    
def stack_shifted_sales(df, days_delta=90):
    names = storeitems_column_names()
    dfs = [df.copy()]
    abs_range = range(1, days_delta+1) if days_delta > 0 else range(days_delta, 0)
    for day_offset in abs_range:
        delta = -day_offset
        shifted = shift_series_in_df(df, series_names=names, days_delta=delta)
        dfs.append(shifted)
    return pd.concat(dfs, axis=1, copy=False)

# %%
df_total = stack_shifted_sales(df_total, days_delta=-1)

# %%
# remove 1st row
df_total = df_total.dropna()  

df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1915 entries, 2013-01-02 to 2018-03-31
# Columns: 1077 entries, weekday_0 to item_50_store_10_sales_past_1
# dtypes: bool(1), float64(1000), uint8(76)
# memory usage: 14.8 MB

# %%
# ensure stacked and standard sales columns in same order
sales_cols = [col for col in df_total.columns if '_sales' in col and '_sales_' not in col]
stacked_sales_cols = [col for col in df_total.columns if '_sales_' in col]
other_cols = [col for col in df_total.columns if col not in set(sales_cols) and col not in set(stacked_sales_cols)]

sales_cols = sorted(sales_cols)
stacked_sales_cols = sorted(stacked_sales_cols)

new_cols = other_cols + stacked_sales_cols + sales_cols

# %%
df_total = df_total.reindex(columns=new_cols)

# %%
df_total.head()
# Out:
#             weekday_0  weekday_1  weekday_2  weekday_3  weekday_4  weekday_5  \
# date
# 2013-01-02          0          0          1          0          0          0
# 2013-01-03          0          0          0          1          0          0
# 2013-01-04          0          0          0          0          1          0
# 2013-01-05          0          0          0          0          0          1
# 2013-01-06          0          0          0          0          0          0
#
#             ...  item_9_store_4_sales  item_9_store_5_sales  \
# date        ...
# 2013-01-02  ...                  21.0                  20.0
# 2013-01-03  ...                  25.0                  15.0
# 2013-01-04  ...                  37.0                  20.0
# 2013-01-05  ...                  37.0                  23.0
# 2013-01-06  ...                  37.0                  29.0
#
#             item_9_store_6_sales  item_9_store_7_sales  item_9_store_8_sales  \
# date
# 2013-01-02                  17.0                  20.0                  28.0
# 2013-01-03                  28.0                  18.0                  31.0
# 2013-01-04                  33.0                  24.0                  46.0
# 2013-01-05                  27.0                  14.0                  35.0
# 2013-01-06                  20.0                  24.0                  34.0
#
#             item_9_store_9_sales
# date
# 2013-01-02                  36.0
# 2013-01-03                  25.0
# 2013-01-04                  31.0
# 2013-01-05                  30.0
# 2013-01-06                  35.0
#
# [5 rows x 1077 columns]

# %%
df_total.describe()
# Out:
#          weekday_0    weekday_1    weekday_2    weekday_3    weekday_4  \
# count  1915.000000  1915.000000  1915.000000  1915.000000  1915.000000
# mean      0.142559     0.142559     0.143081     0.143081     0.143081
# std       0.349714     0.349714     0.350247     0.350247     0.350247
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#          weekday_5  ...  item_9_store_4_sales  item_9_store_5_sales  \
# count  1915.000000  ...           1915.000000           1915.000000
# mean      0.143081  ...             51.522193             37.021410
# std       0.350247  ...             18.707446             13.864136
# min       0.000000  ...              0.000000              0.000000
# 25%       0.000000  ...             41.000000             29.000000
# 50%       0.000000  ...             52.000000             38.000000
# 75%       0.000000  ...             64.000000             46.000000
# max       1.000000  ...            111.000000             84.000000
#
#        item_9_store_6_sales  item_9_store_7_sales  item_9_store_8_sales  \
# count           1915.000000           1915.000000           1915.000000
# mean              37.613055             34.219321             60.241253
# std               13.968996             12.788732             21.714863
# min                0.000000              0.000000              0.000000
# 25%               30.000000             27.000000             48.000000
# 50%               38.000000             35.000000             61.000000
# 75%               46.000000             42.000000             74.000000
# max               81.000000             78.000000            134.000000
#
#        item_9_store_9_sales
# count           1915.000000
# mean              51.577023
# std               18.706826
# min                0.000000
# 25%               41.000000
# 50%               52.000000
# 75%               63.000000
# max              110.000000
#
# [8 rows x 1076 columns]

# %%
assert df_total.isna().any().any() == False

# %% [markdown]
# ### Scaling

# %%
cols_to_scale = [col for col in df_total.columns if 'weekday' not in col and 'month' not in col and 'weekyear' not in col and 'quarter' not in col]

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_cols = scaler.fit_transform(df_total[cols_to_scale])
df_total[cols_to_scale] = scaled_cols

df_total.head()
# Out:
#             weekday_0  weekday_1  weekday_2  weekday_3  weekday_4  weekday_5  \
# date
# 2013-01-02          0          0          1          0          0          0
# 2013-01-03          0          0          0          1          0          0
# 2013-01-04          0          0          0          0          1          0
# 2013-01-05          0          0          0          0          0          1
# 2013-01-06          0          0          0          0          0          0
#
#             ...  item_9_store_4_sales  item_9_store_5_sales  \
# date        ...
# 2013-01-02  ...              0.189189              0.238095
# 2013-01-03  ...              0.225225              0.178571
# 2013-01-04  ...              0.333333              0.238095
# 2013-01-05  ...              0.333333              0.273810
# 2013-01-06  ...              0.333333              0.345238
#
#             item_9_store_6_sales  item_9_store_7_sales  item_9_store_8_sales  \
# date
# 2013-01-02              0.209877              0.256410              0.208955
# 2013-01-03              0.345679              0.230769              0.231343
# 2013-01-04              0.407407              0.307692              0.343284
# 2013-01-05              0.333333              0.179487              0.261194
# 2013-01-06              0.246914              0.307692              0.253731
#
#             item_9_store_9_sales
# date
# 2013-01-02              0.327273
# 2013-01-03              0.227273
# 2013-01-04              0.281818
# 2013-01-05              0.272727
# 2013-01-06              0.318182
#
# [5 rows x 1077 columns]

# %%
df_total.describe()
# Out:
#          weekday_0    weekday_1    weekday_2    weekday_3    weekday_4  \
# count  1915.000000  1915.000000  1915.000000  1915.000000  1915.000000
# mean      0.142559     0.142559     0.143081     0.143081     0.143081
# std       0.349714     0.349714     0.350247     0.350247     0.350247
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#          weekday_5  ...  item_9_store_4_sales  item_9_store_5_sales  \
# count  1915.000000  ...           1915.000000           1915.000000
# mean      0.143081  ...              0.464164              0.440731
# std       0.350247  ...              0.168536              0.165049
# min       0.000000  ...              0.000000              0.000000
# 25%       0.000000  ...              0.369369              0.345238
# 50%       0.000000  ...              0.468468              0.452381
# 75%       0.000000  ...              0.576577              0.547619
# max       1.000000  ...              1.000000              1.000000
#
#        item_9_store_6_sales  item_9_store_7_sales  item_9_store_8_sales  \
# count           1915.000000           1915.000000           1915.000000
# mean               0.464359              0.438709              0.449562
# std                0.172457              0.163958              0.162051
# min                0.000000              0.000000              0.000000
# 25%                0.370370              0.346154              0.358209
# 50%                0.469136              0.448718              0.455224
# 75%                0.567901              0.538462              0.552239
# max                1.000000              1.000000              1.000000
#
#        item_9_store_9_sales
# count           1915.000000
# mean               0.468882
# std                0.170062
# min                0.000000
# 25%                0.372727
# 50%                0.472727
# 75%                0.572727
# max                1.000000
#
# [8 rows x 1077 columns]

# %% [markdown]
# ### Split back to train and test data

# %%
df_train = df_total[df_total['is_test'] == False].drop('is_test', axis=1)
df_test = df_total[df_total['is_test'] == True].drop('is_test', axis=1)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1825 entries, 2013-01-02 to 2017-12-31
# Columns: 1076 entries, weekday_0 to item_9_store_9_sales
# dtypes: float64(1000), uint8(76)
# memory usage: 14.1 MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 90 entries, 2018-01-01 to 2018-03-31
# Columns: 1076 entries, weekday_0 to item_9_store_9_sales
# dtypes: float64(1000), uint8(76)
# memory usage: 710.5 KB

# %% [markdown]
# ### Prepare training data

# %%
X_cols_stacked = [col for col in df_train.columns if '_past_' in col]
X_cols_caldata = [col for col in df_train.columns if 'weekday_' in col or 'month_' in col or 'weekyear_' in col or 'quarter_' in col]
X_cols = X_cols_stacked + X_cols_caldata

X = df_train[X_cols]

# %%
X_colset = set(X_cols)
y_cols = [col for col in df_train.columns if col not in X_colset]

y = df_train[y_cols]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1825 entries, 2013-01-02 to 2017-12-31
# Columns: 576 entries, item_10_store_10_sales_past_1 to quarter_4
# dtypes: float64(500), uint8(76)
# memory usage: 7.1 MB

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1825 entries, 2013-01-02 to 2017-12-31
# Columns: 500 entries, item_10_store_10_sales to item_9_store_9_sales
# dtypes: float64(500)
# memory usage: 7.0 MB

# %%
# split training data into train and val (80-20)
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
X_train.shape, X_valid.shape
# Out:
# ((1460, 576), (365, 576))

# %%
y_train.shape, y_valid.shape
# Out:
# ((1460, 500), (365, 500))

# %%
# reshape inputs to be 3d
X_train_vals = X_train.values.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_valid_vals = X_valid.values.reshape((X_valid.shape[0], 1, X_valid.shape[1]))

# %%
X_train_vals.shape, X_valid_vals.shape
# Out:
# ((1460, 1, 576), (365, 1, 576))

# %% [markdown]
# ## LSTM-CNN model

# %%
early_stop = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)

# %%
cp = ModelCheckpoint("lstm-cnn-base_regressor.hdf5", monitor='loss', verbose=1,save_best_only=True)

# %%
def build_model():
    inputs = Input(shape=(X_train_vals.shape[1], X_train_vals.shape[2]))
    
    # top pipeline
    top_lstm = LSTM(500, return_sequences=True)(inputs)
    top_dense = Dense(500, activation='relu')(top_lstm)
    
    # bottom pipeline
    bottom_dense = Dense(500)(inputs)
    bottom_conv1 = Conv1D(
        500, 
        kernel_size=1,
        input_shape=(X_train_vals.shape[1], X_train_vals.shape[2])
    )(bottom_dense)
    bottom_conv2 = Conv1D(
        1000,
        kernel_size=50,
        padding='same',
        activation='relu'
    )(bottom_conv1)
    bottom_conv3 = Conv1D(
        500,
        kernel_size=10,
        padding='same',
        activation='relu'
    )(bottom_conv2)
    bottom_pooling = AvgPool1D(
        pool_size=10, 
        padding='same'
    )(bottom_conv3)

    # concat output
    final_concat = Concatenate()([top_dense, bottom_pooling])
    final_lstm = LSTM(1000, dropout=0.2)(final_concat)
    final_dense = Dense(500)(final_lstm)
    
    # compile and return
    model = Model(inputs=inputs, outputs=final_dense)
    model.compile(loss='mse', optimizer='adam', metrics=['mse'])
    model.summary()
    
    return model

# %%
model = build_model()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_14 (InputLayer)          [(None, 1, 576)]     0           []
#
#  dense_19 (Dense)               (None, 1, 500)       288500      ['input_14[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 1, 500)       250500      ['dense_19[0][0]']
#
#  conv1d_16 (Conv1D)             (None, 1, 1000)      25001000    ['conv1d_15[0][0]']
#
#  lstm_15 (LSTM)                 (None, 1, 500)       2154000     ['input_14[0][0]']
#
#  conv1d_17 (Conv1D)             (None, 1, 500)       5000500     ['conv1d_16[0][0]']
#
#  dense_18 (Dense)               (None, 1, 500)       250500      ['lstm_15[0][0]']
#
#  average_pooling1d_4 (AveragePo  (None, 1, 500)      0           ['conv1d_17[0][0]']
#  oling1D)
#
#  concatenate_2 (Concatenate)    (None, 1, 1000)      0           ['dense_18[0][0]',
#                                                                   'average_pooling1d_4[0][0]']
#
#  lstm_16 (LSTM)                 (None, 1000)         8004000     ['concatenate_2[0][0]']
#
#  dense_20 (Dense)               (None, 500)          500500      ['lstm_16[0][0]']
#
# ==================================================================================================
# Total params: 41,449,500
# Trainable params: 41,449,500
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
t0 = time.time()

history = model.fit(
    X_train_vals, 
    y_train.values, 
    epochs=200, 
    batch_size=50,
    validation_data=(X_valid_vals, y_valid.values),
    verbose=2,
    shuffle=False,
    callbacks=[early_stop, cp]
)

t1 = time.time()
train_time = t1 - t0
# Out:
# Epoch 1/200
#
# Epoch 1: loss improved from inf to 0.05259, saving model to lstm-cnn-base_regressor.hdf5
# 30/30 - 8s - loss: 0.0526 - mse: 0.0526 - val_loss: 0.0173 - val_mse: 0.0173 - 8s/epoch - 262ms/step
# Epoch 2/200
#
# Epoch 2: loss improved from 0.05259 to 0.01582, saving model to lstm-cnn-base_regressor.hdf5
# 30/30 - 4s - loss: 0.0158 - mse: 0.0158 - val_loss: 0.0124 - val_mse: 0.0124 - 4s/epoch - 135ms/step
# Epoch 3/200
#
# Epoch 3: loss improved from 0.01582 to 0.01064, saving model to lstm-cnn-base_regressor.hdf5
# 30/30 - 4s - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0117 - val_mse: 0.0117 - 4s/epoch - 137ms/step
# Epoch 4/200
#
# Epoch 4: loss did not improve from 0.01064
# 30/30 - 2s - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0179 - val_mse: 0.0179 - 2s/epoch - 77ms/step
# Epoch 5/200
#
# Epoch 5: loss did not improve from 0.01064
# 30/30 - 2s - loss: 0.0211 - mse: 0.0211 - val_loss: 0.0160 - val_mse: 0.0160 - 2s/epoch - 76ms/step
# Epoch 6/200
#
# Epoch 6: loss did not improve from 0.01064
# 30/30 - 2s - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0129 - val_mse: 0.0129 - 2s/epoch - 75ms/step
# Epoch 7/200
#
# Epoch 7: loss did not improve from 0.01064
# 30/30 - 2s - loss: 0.0157 - mse: 0.0157 - val_loss: 0.0127 - val_mse: 0.0127 - 2s/epoch - 74ms/step
# Epoch 8/200
#
# Epoch 8: loss improved from 0.01064 to 0.01011, saving model to lstm-cnn-base_regressor.hdf5
# 30/30 - 4s - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0108 - val_mse: 0.0108 - 4s/epoch - 131ms/step
# Epoch 9/200
#
# Epoch 9: loss improved from 0.01011 to 0.00907, saving model to lstm-cnn-base_regressor.hdf5
# 30/30 - 4s - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0077 - val_mse: 0.0077 - 4s/epoch - 133ms/step
# Epoch 10/200
#
# Epoch 10: loss did not improve from 0.00907
# 30/30 - 2s - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0090 - val_mse: 0.0090 - 2s/epoch - 76ms/step
# Epoch 11/200
#
# Epoch 11: loss did not improve from 0.00907
# 30/30 - 2s - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0081 - val_mse: 0.0081 - 2s/epoch - 74ms/step
# Epoch 12/200
#
# Epoch 12: loss did not improve from 0.00907
# 30/30 - 2s - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0087 - val_mse: 0.0087 - 2s/epoch - 75ms/step
# Epoch 13/200
#
# Epoch 13: loss did not improve from 0.00907
# 30/30 - 2s - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0092 - val_mse: 0.0092 - 2s/epoch - 75ms/step
# Epoch 14/200
#
# Epoch 14: loss improved from 0.00907 to 0.00719, saving model to lstm-cnn-base_regressor.hdf5
# 30/30 - 4s - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0071 - val_mse: 0.0071 - 4s/epoch - 132ms/step
# Epoch 15/200
#
# Epoch 15: loss did not improve from 0.00719
# 30/30 - 2s - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0180 - val_mse: 0.0180 - 2s/epoch - 75ms/step
# Epoch 16/200
#
# Epoch 16: loss did not improve from 0.00719
# 30/30 - 2s - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0071 - val_mse: 0.0071 - 2s/epoch - 75ms/step
# Epoch 17/200
#
# Epoch 17: loss did not improve from 0.00719
# 30/30 - 2s - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0070 - val_mse: 0.0070 - 2s/epoch - 75ms/step
# Epoch 18/200
#
# Epoch 18: loss did not improve from 0.00719
# 30/30 - 2s - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0086 - val_mse: 0.0086 - 2s/epoch - 75ms/step
# Epoch 19/200
#
# Epoch 19: loss did not improve from 0.00719
# 30/30 - 2s - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0089 - val_mse: 0.0089 - 2s/epoch - 75ms/step
# Epoch 20/200
#
# Epoch 20: loss did not improve from 0.00719
# 30/30 - 2s - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0082 - val_mse: 0.0082 - 2s/epoch - 75ms/step
# Epoch 21/200
#
# Epoch 21: loss did not improve from 0.00719
# 30/30 - 2s - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0084 - val_mse: 0.0084 - 2s/epoch - 74ms/step
# Epoch 22/200
#
# Epoch 22: loss did not improve from 0.00719
# 30/30 - 2s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0086 - val_mse: 0.0086 - 2s/epoch - 74ms/step
# Epoch 23/200
#
# Epoch 23: loss did not improve from 0.00719
# 30/30 - 2s - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0075 - val_mse: 0.0075 - 2s/epoch - 75ms/step
# Epoch 24/200
#
# Epoch 24: loss did not improve from 0.00719
# 30/30 - 2s - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0080 - val_mse: 0.0080 - 2s/epoch - 81ms/step

# %% [markdown]
# ## Model evaluation

# %%
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
def model_eval(model, X_test, y_test, log_all=False):
    sales_x_cols = [col for col in X_test.columns if 'sales' in col]
    sales_x_idxs = [X_test.columns.get_loc(col) for col in sales_x_cols]
    sales_y_cols = [col for col in y_test.columns if 'sales' in col]
    sales_y_idxs = [y_test.columns.get_loc(col) for col in sales_y_cols]
    n_samples = y_test.shape[0]
    y_pred = np.zeros(y_test.shape)

    x_next = X_test.iloc[0].values
    for i in range(0, n_samples):
        if log_all:
            print('[x]', x_next)
        x_arr = np.array([x_next])
        x_arr = x_arr.reshape(x_arr.shape[0], 1, x_arr.shape[1])
        y_pred[i] = model.predict(x_arr)[0]
        try:
            x_next = X_test.iloc[i+1].values
            x_next[sales_x_idxs] = y_pred[i][sales_y_idxs]
        except IndexError:
            pass 
    return y_pred, y_test.values

# %%
# define smape metric
def calculate_smape(actual, predicted) -> float:
    if not all([isinstance(actual, np.ndarray), 
                isinstance(predicted, np.ndarray)]):
        actual, predicted = np.array(actual), np.array(predicted)
  
    result = np.mean(np.abs(predicted - actual) / ((np.abs(predicted) + np.abs(actual))/2)) * 100

    return result

# %%
def unscale(y_arr, scaler, template_df, toint=False):
    tmp = template_df.copy()
    tmp[y_cols] = pd.DataFrame(y_arr, index=tmp.index)
    tmp[cols_to_scale] = scaler.inverse_transform(tmp[cols_to_scale])
    if toint:
        return tmp[y_cols].astype(int)
    return tmp[y_cols]

# %%
best_model = models.load_model("lstm-cnn-base_regressor.hdf5")
y_pred, y_real = model_eval(best_model, X_valid, y_valid)
# Out:
# 1/1 [==============================] - 1s 722ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step

# %%
template_df = pd.concat([X_valid, y_valid], axis=1)
template_df['is_test'] = np.repeat(True, template_df.shape[0])

pred = unscale(y_pred, scaler, template_df, toint=True)
real = unscale(y_real, scaler, template_df, toint=True)

# %%
smape = calculate_smape(pred,real)
mse = mean_squared_error(pred,real)
r2 = r2_score(pred,real)

# %%
print("SMAPE:", smape)
print("\nMean squared error (MSE):", mse)
print("\nR2 score:", r2)
print("\nTraining time: %fs" % (train_time))
# Out:
# SMAPE: 12.59768272781995
#
# Mean squared error (MSE): 72.77613150684931
#
# R2 score: 0.38370631622033236
#
# Training time: 68.795271s

# %% [markdown]
# ## Predict on test

# %%
# prepare test data
X_test, y_test = df_test[X_cols], df_test[y_cols]

# %%
y_test_pred, _ = model_eval(model, X_test, y_test)
# Out:
# 1/1 [==============================] - 1s 756ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 36ms/step

# %%
test_template_df = pd.concat([X_test, y_test], axis=1)
test_template_df['is_test'] = np.repeat(True, test_template_df.shape[0])

test_pred = unscale(y_test_pred, scaler, test_template_df, toint=True)

# %%
test_pred.head()
# Out:
#             item_10_store_10_sales  item_10_store_1_sales  \
# date
# 2018-01-01                      59                     46
# 2018-01-02                      60                     48
# 2018-01-03                      59                     47
# 2018-01-04                      61                     49
# 2018-01-05                      65                     52
#
#             item_10_store_2_sales  item_10_store_3_sales  \
# date
# 2018-01-01                     67                     60
# 2018-01-02                     69                     61
# 2018-01-03                     68                     60
# 2018-01-04                     70                     62
# 2018-01-05                     74                     66
#
#             item_10_store_4_sales  item_10_store_5_sales  ...  \
# date                                                      ...
# 2018-01-01                     54                     38  ...
# 2018-01-02                     57                     39  ...
# 2018-01-03                     56                     38  ...
# 2018-01-04                     58                     40  ...
# 2018-01-05                     61                     43  ...
#
#             item_9_store_4_sales  item_9_store_5_sales  item_9_store_6_sales  \
# date
# 2018-01-01                    37                    27                    27
# 2018-01-02                    39                    28                    28
# 2018-01-03                    38                    27                    28
# 2018-01-04                    39                    29                    29
# 2018-01-05                    42                    30                    30
#
#             item_9_store_7_sales  item_9_store_8_sales  item_9_store_9_sales
# date
# 2018-01-01                    25                    45                    38
# 2018-01-02                    26                    46                    39
# 2018-01-03                    26                    46                    38
# 2018-01-04                    27                    47                    40
# 2018-01-05                    28                    50                    42
#
# [5 rows x 500 columns]

# %%
result = np.zeros(45000, dtype=np.int)
for i, s in storeitems():
    slice_start_idx = 90*10*(i-1) + 90*(s-1)
    slice_end_idx = slice_start_idx + 90
    col_name = f'item_{i}_store_{s}_sales'
    result[slice_start_idx:slice_end_idx] = test_pred[col_name].values
result = pd.DataFrame(result, columns=['sales'])
result.index.name = 'id'
result.head()
# Out:
#     sales
# id
# 0      14
# 1      14
# 2      14
# 3      14
# 4      15

# %%
result.to_csv('lstm-cnn-base_submission.csv')
